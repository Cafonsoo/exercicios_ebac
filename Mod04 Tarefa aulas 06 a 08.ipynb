# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
data_json = r.json()

# %%
print(data_json['items'])
# Out:
# [{'id_pleito': 5467, 'tipo_interessado': 'Município', 'interessado': 'Varzelândia', 'cod_ibge': 3170909, 'uf': 'MG', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000120/2014-63', 'data_protocolo': '2014-03-31T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco de Desenvolvimento de Minas Gerais S/A', 'moeda': 'Real', 'valor': 2000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '02/05/2014'}, {'id_pleito': 5471, 'tipo_interessado': 'Município', 'interessado': 'Varzelândia', 'cod_ibge': 3170909, 'uf': 'MG', 'num_pvl': None, 'status': 'Regularizado', 'num_processo': '17944.000121/2014-16', 'data_protocolo': '2014-03-31T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Regularização de Dívida - Água e Esgoto', 'tipo_credor': 'Empresa Estatal', 'credor': 'Companhia de Saneamento de Minas Gerais', 'moeda': 'Real', 'valor
# ...

# %%
df = pd.DataFrame(data_json['items'])
df
# Out:
#       id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0          5467        Município     Varzelândia   3170909  MG    None
# 1          5471        Município     Varzelândia   3170909  MG    None
# 2          5475        Município     Nova Iguaçu   3303500  RJ    None
# 3          5280        Município  Porto Barreiro   4120150  PR    None
# 4          5289        Município          Frutal   3127107  MG    None
# ...         ...              ...             ...       ...  ..     ...
# 4995      15681        Município     Pato Branco   4118501  PR    None
# 4996      15685        Município      Califórnia   4103503  PR    None
# 4997      15289        Município            Verê   4128609  PR    None
# 4998      18368           Estado           Bahia        29  BA    None
# 4999      18373           Estado         Paraíba        25  PB    None
#
#                               status          num_processo  \
# ...

# %%
dfRJ = df[df["uf"]=='RJ']
dfRJ.head(5)
# Out:
#      id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 2         5475        Município     Nova Iguaçu   3303500  RJ    None
# 85       10923        Município         Niterói   3303302  RJ    None
# 296       6676        Município   Volta Redonda   3306305  RJ    None
# 304       7129           Estado  Rio de Janeiro        33  RJ    None
# 306       7141           Estado  Rio de Janeiro        33  RJ    None
#
#                                                 status          num_processo  \
# 2                                            Arquivado  17944.000122/2010-29
# 85                                            Deferido  17944.001314/2014-86
# 296                                          Arquivado  17944.000407/2008-45
# 304  Encaminhado à PGFN com manifestação técnica fa...  17944.000504/2014-86
# 306  Encaminhado à PGFN com manifestação técnica fa...  17944.000506/2014-75
#
#            data_protocolo                                      tipo_operacao  \
# ...

# %%
# 2) Seu código aqui
dfRJ.status.value_counts()
# Out:
# Deferido                                                 23
# Arquivado                                                11
# Encaminhado à PGFN com manifestação técnica favorável    10
# Deferido (PVL-IF)                                         5
# Arquivado por decurso de prazo                            4
# Regularizado                                              3
# Em retificação pelo interessado                           2
# Arquivado a pedido                                        2
# Name: status, dtype: int64

# %%
dfRJ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 2 to 4966
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              60 non-null     int64
#  1   tipo_interessado       60 non-null     object
#  2   interessado            60 non-null     object
#  3   cod_ibge               60 non-null     int64
#  4   uf                     60 non-null     object
#  5   num_pvl                18 non-null     object
#  6   status                 60 non-null     object
#  7   num_processo           55 non-null     object
#  8   data_protocolo         55 non-null     object
#  9   tipo_operacao          60 non-null     object
#  10  finalidade             60 non-null     object
#  11  tipo_credor            60 non-null     object
#  12  credor                 60 non-null     object
#  13  moeda                  60 non-null     object
# ...

# %%
# 3) Seu código aqui
dfStatus = dfRJ
dfStatus['ano'] = dfRJ['data_status'].str.slice(6,)
dfStatus['ano']
# Out:
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_6588\1618158901.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfStatus['ano'] = dfRJ['data_status'].str.slice(6,)
# 2       2010
# 85      2015
# 296     2008
# 304     2014
# 306     2014
# 381     2010
# 636     2013
# 772     2008
# 823     2010
# 874     2020
# 894     2021
# 902     2023
# 1104    2020
# 1138    2019
# 1145    2019
# 1158    2019
# 1299    2020
# 1309    2008
# 1337    2021
# 1376    2010
# 1383    2013
# 1393    2012
# 1408    2011
# 1416    2007
# 1555    2023
# 1818    2023
# 1872    2023
# 2072    2020
# 2097    2022
# 2333    2012
# 2377    2015
# 2424    2007
# 2575    2012
# 2702    2014
# 2796    2007
# 2807    2011
# 2821    2008
# 2940    2008
# ...

# %%
#ano = dfRJ.iloc[0,17]
#ano = ano[-4:]
#ano

# %%
# 4)

dfStatus['ano'].value_counts()
# Out:
# 2008    9
# 2010    8
# 2023    7
# 2014    5
# 2020    5
# 2012    5
# 2009    4
# 2019    3
# 2007    3
# 2015    2
# 2013    2
# 2021    2
# 2011    2
# 2022    1
# 2002    1
# 2016    1
# Name: ano, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta(uf, interessado):

    """
    Retorna um DataFrame com os registros que correspondem ao estado (UF) e ao tipo de interessado.
    Argumentos:
        uf: Sigla do estado (UF).
        interessado: Tipo de interessado.
    Retorno:
        Um DataFrame com os registros filtrados.
    """
    #dfReturn = df[df["uf"]==uf.upper()] & df[df['tipo_interessado']==interessado.capitalize()]
    #dfReturn2 = dfReturn[df['tipo_interessado']==interessado.capitalize()]
    try: 
        dfReturn = df[(df["uf"]==uf.upper()) & (df['tipo_interessado']==interessado.capitalize())]
    except: 
        dfReturn = df[(df["uf"]==uf.upper())]
    return dfReturn

# %%
consulta('rj','eStado')
# Out:
#       id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 304        7129           Estado  Rio de Janeiro        33  RJ    None
# 306        7141           Estado  Rio de Janeiro        33  RJ    None
# 381        4997           Estado  Rio de Janeiro        33  RJ    None
# 1408       9050           Estado  Rio de Janeiro        33  RJ    None
# 2575      10561           Estado  Rio de Janeiro        33  RJ    None
# 3344      13634           Estado  Rio de Janeiro        33  RJ    None
# 3591       7525           Estado  Rio de Janeiro        33  RJ    None
# 3810      12018           Estado  Rio de Janeiro        33  RJ    None
# 4039       5943           Estado  Rio de Janeiro        33  RJ    None
# 4679      13364           Estado  Rio de Janeiro        33  RJ    None
#
#                                                  status          num_processo  \
# 304   Encaminhado à PGFN com manifestação técnica fa...  17944.000504/2014-86
# ...

# %%
# 2) Seu código aqui
eMG = consulta('mg', 'estado')
#eMG = eMG[eMG['status'] == 'Arquivado por decurso de prazo']
#eMG.value_counts()
eMG.value_counts(eMG['status'] == 'Arquivado por decurso de prazo')
# Out:
# status
# False    7
# dtype: int64

# %%
# 3) Seu código aqui
eBA = consulta('ba', 'município')
eBA.value_counts(eBA['status'] == 'Deferido')
# Out:
# status
# False    118
# True      85
# dtype: int64

# %%
# 4) Seu código aqui
eEBA = consulta('ba', 'estado')
eEBA.to_csv('./output/solicitacoes_Estado_Bahia.csv', index= False, sep=';', decimal=',')
